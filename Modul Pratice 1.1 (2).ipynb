# %%
import statistics
import matplotlib.pyplot as plt


data = [95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75]

mean = statistics.mean(data)
median = statistics.median(data)
mode = statistics.mode(data)

def mean(data) : 
    return sum(data) / len(data)


def median(data) :
    data.sort()
    n = len(data)
    if n%2 == 0 :
        median = (data[n//2 - 1] + data[n//2]) / 2
    else : 
        data[n//2]
    return median

def modus(data) :
    modus = max(set(data), key = data.count)
    return modus

mean_manual = mean(data_nilai_uas)
modus_manual = modus(data_nilai_uas)
median_manual = median(data_nilai_uas)

mean_stats = statistics.mean(data_nilai_uas)
modus_stats = statistics.mode(data_nilai_uas)
median_stats = statistics.median(data_nilai_uas)

# HASIL
print(f"Mean (Manual) : {mean_manual}")
print(f"Median (Manual) : {median_manual}")
print(f"Modus (Manual) : {modus_manual}")
print(f"Mean (Statistics) : {mean_stats}")
print(f"Modus (statistics) : {modus_stats}")
print(f"Median (Statistics) : {median_stats}")


plt.hist(data_nilai_uas, bins = 17, color ='green', edgecolor='yellow')
plt.xlabel('Nilai UAS')
plt.ylabel('Frekuensi')
plt.title('Distribusi Nilai UAS Matematika')
plt.show()
# Out:
# Mean (Manual) : 60.75
# Median (Manual) : 62.5
# Modus (Manual) : 35
# Mean (Statistics) : 60.75
# Modus (statistics) : 35
# Median (Statistics) : 62.5
